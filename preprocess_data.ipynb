# %% [markdown]
# importing modules and defining functions... with variables

# %%
import pandas as pd
import numpy as np
import os
import openai
from dotenv import load_dotenv

load_dotenv()

openai_api_key = os.getenv('OPENAI_API_KEY')
openai.api_key = openai_api_key

# imports
import tiktoken

from openai.embeddings_utils import get_embedding
# embedding model parameters
embedding_model = "text-embedding-ada-002"
embedding_encoding = "cl100k_base"  # this the encoding for text-embedding-ada-002
max_tokens = 8000  # the maximum for text-embedding-ada-002 is 8191
input_datapath = "data/BigBazaar.csv"  # to save space, we provide a pre-filtered dataset
df = pd.read_csv(input_datapath)

# %% [markdown]
# let's create embedding and vector db for bigbaazar data

# %%
df.head(2)
# Out:
#                                    Name     Brand Price  DiscountedPrice  \
# 0  Glass Water Tumbler Set - Acme Elite      Treo   550            299.0
# 1                           Papad Plain  NILGIRIS    85             42.5
#
#                         BreadCrumbs       Category       SubCategory  \
# 0      Serveware / Dining & Serving      Serveware  Dining & Serving
# 1  Packaged Food / Pickles & Papads  Packaged Food  Pickles & Papads
#
#    Quantity                                        Description  \
# 0  6*300 ml
# 1     200 g  Nilgiris plain papad can be enjoyed when you'r...
#
#                                      LongDescription
# 0             Design:Made from premium quality Glass
# 1  Nilgiris plain papad can be enjoyed when you'r...

# %%
df.columns
# Out:
# Index(['Name', 'Brand', 'Price', 'DiscountedPrice', 'BreadCrumbs', 'Category',
#        'SubCategory', 'Quantity', 'Description', 'LongDescription'],
#       dtype='object')

# %%
# load & inspect dataset
# columns: Brand	Price	DiscountedPrice	BreadCrumbs	Category	SubCategory	Quantity	Description	LongDescription
df = df.dropna()
# convert all columns to string
df = df.astype(str)

# %%
len(df)
# Out:
# 8219

# %%
# add all columns data into one columns
df["combined"] = (
    "Name: " + df.Name.str.strip() +" ; "+ 
    "Brand: " + df.Brand.str.strip() +" ; "+ 
    "Price: " + df.Price.str.strip() +" ; "+
    "DiscountedPrice: " + df.DiscountedPrice.str.strip() +" ; "+
    "BreadCrumbs: " + df.BreadCrumbs.str.strip() +" ; "+
    "Category: " + df.Category.str.strip() +" ; "+
    "SubCategory: " + df.SubCategory.str.strip() +" ; "+
    "Quantity: " + df.Quantity.str.strip() +" ; "+
    "Description: " + df.Description.str.strip() +" ; "+
    "LongDescription: " + df.LongDescription.str.strip()
)

# %%
encoding = tiktoken.get_encoding(embedding_encoding)
top_n = 500
df["n_tokens"] = df.combined.apply(lambda x: len(encoding.encode(x)))
df = df[df.n_tokens <= max_tokens].tail(top_n)
len(df)
# Out:
# 8000

# %%
#calculate avg number of words in df.combined
df["n_words"] = df.combined.apply(lambda x: len(x.split()))
df.n_words.max()
# Out:
# 429

# %%
# which row have the most words in df.combined using df.n_words.max()
df[df.n_words == df.n_words.max()]
# Out:
#                      Name    Brand Price DiscountedPrice  \
# 3287  Mouthwash Fresh Tea  Colgate   150           99.99
#
#                     BreadCrumbs       Category SubCategory Quantity  \
# 3287  Personal Care / Oral Care  Personal Care   Oral Care   250 ml
#
#      Description                                    LongDescription  \
# 3287              Colgate Plax Fresh Tea mouthwash removes over ...
#
#                                                combined  n_tokens  n_words
# 3287  Name: Mouthwash Fresh Tea ; Brand: Colgate ; P...       585      429

# %%
total_tokens = df.n_tokens.sum()
print(total_tokens)
# Out:
# 941007

# %%
df["embedding"] = df.combined.apply(lambda x: get_embedding(x, engine=embedding_model))
df.to_csv("data/BigBazaar_vector_db.csv")

# %%
import ast
import faiss

# %%
df = pd.read_csv("data/BigBazaar_vector_db.csv")

# %%
df1 = pd.read_csv("data/BigBazaar_vector_db_1.csv")

# %%
df1.embedding[0]
# Out:
# '[-0.03161328658461571, -0.007357346825301647, 0.007983220741152763, 0.0010028962278738618, -0.009408081881701946, -0.020813634619116783, -0.036353949457407, -0.01245755236595869, -0.023703306913375854, -0.014341832138597965, 0.01019375305622816, 0.041147876530885696, -0.03371728956699371, -0.02586057409644127, -0.018776215612888336, 0.042985547333955765, 0.009980689734220505, -0.016019707545638084, 0.009254942648112774, -0.018163656815886497, -0.02990878000855446, -0.01693854294717312, -0.01403555367141962, 0.0053665353916585445, -0.026113586500287056, -0.018616417422890663, 0.02443571202456951, -0.0257407259196043, 0.015553630888462067, 0.03395698592066765, 0.008416005410254002, 0.027884677052497864, -0.005496370606124401, -0.01729808747768402, -0.006664890330284834, 0.0016013048589229584, -0.01668553054332733, -0.002658299170434475, 0.032145943492650986, 0.003180970437824726, 0.019095810130238533, 0.022185230627655983, 0.009974031709134579, 0.027005789801478386, -0.021945534273982048, -0.00867567677050829, 0.01913576014339924, -0.008149676024913788, 0.011418867856264114, 0.015220718458294868, 0.0009454689570702612, 0.0171649232506752, -0.01262400858104229, 0.013889072462916374, 0.01640588417649269, 0.0019458683673292398, 0.022398293018341064, 0.02566082775592804, 0.0009687728015705943, -0.025474395602941513, 0.004887142218649387, -0.0022188557777553797, -0.031240426003932953, -0.0034755971282720566, -0.019868165254592896, -0.002441906603053212, -0.012297755107283592, -0.013609427027404308, 0.002598375082015991, 0.012737197801470757, 0.0059591177850961685, 0.009454689919948578, 0.032492171972990036, 0.00340568576939404, 0.013782540336251259, -0.010373525321483612, 0.004680737387388945, 0.013915705494582653, 0.009121778421103954, 0.001522238366305828, 0.02620680257678032, -0.010613222606480122, -0.0016387574141845107, -0.022904319688677788, 0.00940142385661602, 0.010859576985239983, -0.020414140075445175, 0.020427456125617027, -0.016991809010505676, -0.013889072462916374, 0.007996536791324615, 0.037419263273477554, -0.0037319392431527376, 0.014341832138597965, -0.004277914296835661, -0.01659231446683407, -0.01764431595802307, 0.041067976504564285, -0.002107330597937107, -0.03712630271911621, 0.012430919334292412, 0.015753377228975296, -0.0017960581462830305, -0.012710565701127052, -0.03390371799468994, 0.013769224286079407, 0.029828879982233047, -0.023783205077052116, 0.009514614008367062, -0.0010478392941877246, -0.019428720697760582, 0.006278712768107653, 0.009754310362040997, -0.020427456125617027, 0.025487713515758514, 0.019189024344086647, 0.018483253195881844, 0.008635726757347584, 0.028657032176852226, -0.013902388513088226, 0.004657433368265629, 0.02825753763318062, 0.038191620260477066, -0.022211862727999687, 0.036327313631772995, 0.03494240343570709, 0.008748916909098625, -0.00463080033659935, 0.018469935283064842, 0.011552033014595509, 0.020533988252282143, 0.013216590508818626, 0.03683334216475487, -0.0028696979861706495, -0.014568212442100048, 0.03185298293828964, -0.010546639561653137, 0.03883080929517746, -0.029402753338217735, -0.0233304463326931, 0.0005701111513189971, 0.025700775906443596, -0.014741325750946999, 0.00823623314499855, 0.0161129217594862, 0.012923629023134708, 0.0011269057868048549, 0.021652571856975555, -0.008242891170084476, 0.01214461587369442, -0.012637324631214142, -0.007011118344962597, 0.023929687216877937, 0.01612623780965805, 0.0025184762198477983, -0.0028513879515230656, -0.010373525321483612, -0.006421864964067936, 0.005483054090291262, -0.02709900587797165, 0.00564618082717061, -0.003625407349318266, 0.024595510214567184, 0.0008539182599633932, 0.02737865038216114, 0.02448897808790207, 0.014821224845945835, 0.01111258938908577, 0.004011584911495447, -0.011991476640105247, -0.010766361840069294, 0.029669083654880524, -0.0024768623989075422, -0.004624142311513424, -0.023436976596713066, 0.026433181017637253, 0.001676209969446063, -0.024116117507219315, -0.012377653270959854, -0.012078 ...

# %%
df = pd.read_csv("data/BigBazaar_vector_db.csv")
# Apply ast.literal_eval to convert the strings back to lists
df['embedding'] = df['embedding'].apply(ast.literal_eval)
vectors = df.embedding.to_list()
vectors = np.array(vectors)
vectors.shape
dim = vectors.shape[1]
index = faiss.IndexFlatL2(dim)
index.add(vectors)
# Out:
# Traceback (most recent call last):
#
#   File ~/Downloads/LLAMA_chat/say2shop-RAG/venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3526 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[4], line 3
#     df['embedding'] = df['embedding'].apply(ast.literal_eval)
#
#   File ~/Downloads/LLAMA_chat/say2shop-RAG/venv/lib/python3.11/site-packages/pandas/core/series.py:4760 in apply
#     ).apply()
#
#   File ~/Downloads/LLAMA_chat/say2shop-RAG/venv/lib/python3.11/site-packages/pandas/core/apply.py:1207 in apply
#     return self.apply_standard()
#
#   File ~/Downloads/LLAMA_chat/say2shop-RAG/venv/lib/python3.11/site-packages/pandas/core/apply.py:1287 in apply_standard
#     mapped = obj._map_values(
#
#   File ~/Downloads/LLAMA_chat/say2shop-RAG/venv/lib/python3.11/site-packages/pandas/core/base.py:921 in _map_values
#     return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
#   File ~/Downloads/LLAMA_chat/say2shop-RAG/venv/lib/python3.11/site-packages/pandas/core/algorithms.py:1814 in map_array
#     return lib.map_infer(values, mapper, convert=convert)
#
#   File lib.pyx:2917 in pandas._libs.lib.map_infer
#
#   File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ast.py:64 in literal_eval
#     node_or_string = parse(node_or_string.lstrip(" \t"), mode='eval')
#
#   File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ast.py:50 in parse
#     return compile(source, filename, mode, flags,
#
#   File <unknown>:1
#     [ 0.01035868  0.01985359  0.00960615 ... -0.02299457 -0.01084291
#       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df = pd.read_csv("data/BigBazaar_vector_db.csv")

# %%
df['embedding'] = df['embedding'].apply(ast.literal_eval)
df['embedding'] = df['embedding'].apply(np.array)

# %%
type(df.embedding[0])
# Out:
# numpy.ndarray

# %%
#save df to csv
df.to_csv("data/BigBazaar_vector_db.csv",index=False)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Brand', 'Price', 'DiscountedPrice',
#        'BreadCrumbs', 'Category', 'SubCategory', 'Quantity', 'Description',
#        'LongDescription', 'combined', 'n_tokens', 'n_words', 'embedding'],
#       dtype='object')

# %%
#save index as as vector_index.pkl
faiss.write_index(index, "data/vector_index.pkl")

# %%
#load or read index
index = faiss.read_index("data/vector_index.pkl")

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "system", "content": """
        you will first translate the input query into english.
        you will extract data from the translated query in the format of json schema provided.
        json schema:{
  "$schema": "http://json-schema.org/draft-07/schema#",
  "type": "object",
  "properties": {
    "query": {
      "type": "object",
      "properties": {
        "translated_query": {
          "type": "string"
        },
        "items": {
          "type": "array",
          "items": {
            "type": "object",
            "properties": {
              "item_name": {
                "type": "string"
              },
              "brand": {
                "type": "string"
              },
              "quantity": {
                "type": "number"
              },
              "unit": {
                "type": "string"
              },
              "Important_words": {
                "type": "array",
                "items": {
                  "type": "string"
                }
              },
              "features": {
                "type": "array",
                "items": {
                  "type": "string"
                }
              },
              "occasion": {
                "type": "array",
                "items": {
                  "type": "string"
                }
              },
              "price_range": {
                "type": "object",
                "properties": {
                  "minimum_price": {
                    "type": "number"
                  },
                  "maximum_price": {
                    "type": "number"
                  }
                },
                "required": ["minimum_price", "maximum_price"]
              }
            },
            "required": ["item_name"]
          }
        }
      },
      "required": ["translated_query", "items"]
    }
  },
  "required": ["query"]
}
        """},
        {"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message["content"]

# %%
print(get_completion("mujhe mere chote bhai ke liye onelplus ka phone chaiye, jisme 6 gb ram ho aur 128 gb storage ho, aur uska price 20000 se 30000 ke beech ho "))
# Out:
# {
#     "query": {
#         "translated_query": "I want an OnePlus phone for my younger brother with 6GB RAM and 128GB storage, and its price should be between 20000 and 30000.",
#         "items": {
#             "brand": "OnePlus",
#             "quantity": 1,
#             "Important_words": ["phone", "brother"],
#             "features": ["6GB RAM", "128GB storage"],
#             "occasion": [],
#             "price_range": {
#                 "minimum_price": 20000,
#                 "maximum_price": 30000
#             }
#         }
#     }
# }

# %%
search_query = get_completion(input("Enter your search query: "))
print(search_query)
search_vec = get_embedding(search_query, engine=embedding_model)
search_vec = np.array(search_vec).reshape(1, -1)
distances, I = index.search(search_vec, k=5)
I.tolist()
row_indices = I.tolist()[0]
#show only these columns = ['Name', 'Brand', 'Price', 'DiscountedPrice','Category', 'SubCategory', 'Quantity']
# df1 = df[['Name', 'Brand', 'Price', 'DiscountedPrice','Category', 'SubCategory', 'Quantity']]
top_5_results = df[['Name', 'Brand', 'Price', 'DiscountedPrice','Category', 'SubCategory', 'Quantity']].loc[row_indices]
print(top_5_results.to_dict(orient="records"))
# Out:
# {
#     "query": {
#         "translated_query": "phone and wheat",
#         "items": [
#             {
#                 "brand": "phone",
#                 "quantity": 1,
#                 "important_words": ["phone"],
#                 "features": [],
#                 "occasion": [],
#                 "price_range": {
#                     "minimum_price": 0,
#                     "maximum_price": 0
#                 }
#             },
#             {
#                 "brand": "wheat",
#                 "quantity": 1,
#                 "important_words": ["wheat"],
#                 "features": [],
#                 "occasion": [],
#                 "price_range": {
#                     "minimum_price": 0,
#                     "maximum_price": 0
#                 }
#             }
#         ]
#     }
# }
# [{'Name': 'Pizza Wheat Bread Pack of 2', 'Brand': 'NILGIRIS', 'Price': '40', 'DiscountedPrice': 40.0, 'Category': 'Bakery, Dairy & Frozen', 'SubCategory': 'Bread & Bakery', 'Quantity': '150 g'}, {'Name': 'Wheat Daliya Small', 'Brand': 'ektaa', 'Price': '38', 'DiscountedPrice': 33.0, 'Category': 'Staples', 'SubCategory': 'Other Cereals', 'Quantity': '500 g'}, {'Name': 'Whole Wheat Chapati', 'Brand': 'iD', 'Price': '70', 'DiscountedPrice': 70.0, 'Category': 'Bakery, Dairy & Frozen', 'SubCategory': 'Bread & Bakery', 'Quantity': '10 Pcs'}, {'Name': 'Wheat Daliya Big', 'Brand': 'ektaa', 'Price': '38', 'DiscountedPrice': 33.0, 'Category': 'Staples', 'SubCategory': 'Other Cereals', 'Quantity': '500 g'}, {'Name': 'Whole Wheat Parota', 'Brand': 'iD', 'Price': '80', 'DiscountedPrice': 80.0, 'Category': 'Bakery, Dairy & Frozen', 'SubCategory': 'Bread & Bakery', 'Quantity': '400 g'}]

# %%
df.to_csv("data/BigBazaar_vector_db_1.csv")

# %%
# convert search_query to json
import json
search_query = json.loads(search_query)
search_query
# Out:
# {'query': {'translated_query': 'I want rice bag, wheat, biscuits, and chillies',
#   'items': [{'brand': 'rice bag',
#     'quantity': 1,
#     'important_words': ['rice'],
#     'features': [],
#     'occasion': [],
#     'price_range': {'minimum_price': 0, 'maximum_price': 0}},
#    {'brand': 'wheat',
#     'quantity': 1,
#     'important_words': ['wheat'],
#     'features': [],
#     'occasion': [],
#     'price_range': {'minimum_price': 0, 'maximum_price': 0}},
#    {'brand': 'biscuits',
#     'quantity': 1,
#     'important_words': ['biscuits'],
#     'features': [],
#     'occasion': [],
#     'price_range': {'minimum_price': 0, 'maximum_price': 0}},
#    {'brand': 'chillies',
#     'quantity': 1,
#     'important_words': ['chillies'],
#     'features': [],
#     'occasion': [],
#     'price_range': {'minimum_price': 0, 'maximum_price': 0}}]}}

# %%
search_query["query"]["items"][0]
# Out:
# {'brand': 'rice bag',
#  'quantity': 1,
#  'important_words': ['rice'],
#  'features': [],
#  'occasion': [],
#  'price_range': {'minimum_price': 0, 'maximum_price': 0}}

# %%
index = faiss.read_index("data/vector_index.pkl")

# %%
import pickle 
import lzma
with lzma.open("vector_index.xz", "wb") as f:
    pickle.dump(index, f)

# %%
import pandas as pd
df = pd.read_csv("data/BigBazaar_vector_db.csv")
df.head()
# Out:
#    Unnamed: 0                     Name     Brand Price  DiscountedPrice  \
# 0         229  Anti Acne Facewash Neem  Himalaya   210            210.0
# 1         230  Anti Acne Facewash Neem  Himalaya   170            145.0
# 2         231  Anti Acne Facewash Neem  Himalaya   130            117.0
# 3         232              Mango Drink    FROOTI   105            105.0
# 4         233              Mango Drink    FROOTI   100            100.0
#
#                         BreadCrumbs            Category           SubCategory  \
# 0    Skin Care & Beauty / Skin Care  Skin Care & Beauty             Skin Care
# 1    Skin Care & Beauty / Skin Care  Skin Care & Beauty             Skin Care
# 2    Skin Care & Beauty / Skin Care  Skin Care & Beauty             Skin Care
# 3  Beverages / Soft Drinks & Juices           Beverages  Soft Drinks & Juices
# 4  Beverages / Soft Drinks & Juices           Beverages  Soft Drinks & Juices
#
#   Quantity                                        Description  \
# 0   200 ml  Himalaya Turmeric Herbals Purifying Neem Face ...
# 1   150 ml  Himalaya Turmeric Herbals Purifying Neem Face ...
# 2   100 ml  Himalaya Turmeric Herbals Purifying Neem Face ...
# 3   2.25 L
# 4      2 L
#
#                                      LongDescription  \
# 0                           Purifying Neem Face Wash
# 1                           Purifying Neem Face Wash
# 2                           Purifying Neem Face Wash
# 3  Frooti Mango Drink is something that would boo...
# 4  Frooti Mango Drink is something that would boo...
#
#                                             combined  n_tokens  n_words  \
# 0  Name: Anti Acne Facewash Neem ; Brand: Himalay...       118       79
# 1  Name: Anti Acne Facewash Neem ; Brand: Himalay...       118       79
# 2  Name: Anti Acne Facewash Neem ; Brand: Himalay...       118       79
# 3  Name: Mango Drink ; Brand: FROOTI ; Price: 105...       116       73
# 4  Name: Mango Drink ; Brand: FROOTI ; Price: 100...       114       73
#
#                                            embedding
# 0  [ 0.01035868  0.01985359  0.00960615 ... -0.02...
# 1  [ 0.00945115  0.0220004   0.00897402 ... -0.02...
# 2  [ 0.00863239  0.01953785  0.00575493 ... -0.02...
# 3  [-0.00132543 -0.0154933   0.00209192 ... -0.01...
# 4  [ 0.0016192  -0.01780541 -0.00098317 ... -0.02...

# %%
#drop last 4 columns
df = df.iloc[:, :-4]
df.to_csv("data/BigBazaar_vector_db_git.csv",index=False)
